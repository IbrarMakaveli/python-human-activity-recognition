# %% [markdown]
# ## 1. Importing all the required modules

# %%
# Linear algebra import
import numpy as np

# Library to handle dataset
import pandas as pd

# ML models imports

# Metrics to Evaluate the models
from sklearn.metrics import *

# Visualization Libraries imports
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt

# %matplotlib inline
plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Importing the dataset

# %%
df_train = pd.read_csv('dataset/train.csv')
df_test = pd.read_csv('dataset/test.csv')

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# Checking the first five samples of  train data
df_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
df_test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
# Checking count etc
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
# Checking train data stats
df_train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %% [markdown]
# ### 3.1 Check Duplicate Values

# %%
print('Duplicates in train data : ',sum(df_train.duplicated()))
# Out:
# Duplicates in train data :  0

# %%
print('Duplicates in test data : ',sum(df_test.duplicated()))
# Out:
# Duplicates in test data :  0

# %% [markdown]
# ### 3.2 Check Missing Values

# %%
print('Total number of missing values in train data : ', df_train.isnull().values.sum())
# Out:
# Total number of missing values in train data :  0

# %%
print('Total number of missing values in test data : ', df_test.isnull().values.sum())
# Out:
# Total number of missing values in test data :  0

# %% [markdown]
# ### 3.3 Check for Class Imbalance

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of Activities')
sns.countplot(y=df_train.Activity, palette='rainbow')
plt.xticks(rotation=90)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400., 1600.]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# Distribution across classes is almost Uniform

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# As per dataset description activites are split into two categories:
#
# **Static**: Activites with no almost motion i.e. SITTING, STANDING, LAYING
# **Dynamic**: Activites with significant motion i.e. WALKING, WALKING_DOWNSTAIRS, WALKING_UPSTAIRS

# %% [markdown]
# ### 4.1 Analyzing the Difference between two categories of Activites:

# %% [markdown]
# We can consider tBodyAccMag-mean() feature to differentiate among these two categories.

# %%
facetgrid = sns.FacetGrid(df_train, hue='Activity', size=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMag-mean()', hist=False).add_legend()
plt.annotate("Static Activities", xy=(-.996,21), xytext=(-0.9, 23),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Static Activities", xy=(-.999,26), xytext=(-0.9, 23),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Static Activities", xy=(-0.985,12), xytext=(-0.9, 23),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Dynamic Activities", xy=(-0.2,3.25), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Dynamic Activities", xy=(0.1,2.18), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Dynamic Activities", xy=(-0.01,2.15), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
# Out:
# Text(0.1, 9, 'Dynamic Activities')

# %% [markdown]
# This density plot shows an important threshold of seperation between these two activites.
#     if tBodyAccMag-mean < -0.5:
#         'Static activities'
#     else if tBodyAccMag-mean > -0.5:
#         'Dynamic activities'

# %% [markdown]
# Lets take a closer look at density plots of these two categories of activites

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.title("Static Activities")
sns.distplot(df_train[df_train["Activity"]=="SITTING"]['tBodyAccMag-mean()'],hist = False, label = 'Sitting')
sns.distplot(df_train[df_train["Activity"]=="STANDING"]['tBodyAccMag-mean()'],hist = False,label = 'Standing')
sns.distplot(df_train[df_train["Activity"]=="LAYING"]['tBodyAccMag-mean()'],hist = False, label = 'Laying')
plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)
plt.title("Dynamic Activities")
sns.distplot(df_train[df_train["Activity"]=="WALKING"]['tBodyAccMag-mean()'],hist = False, label = 'Sitting')
sns.distplot(df_train[df_train["Activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMag-mean()'],hist = False,label = 'Standing')
sns.distplot(df_train[df_train["Activity"]=="WALKING_UPSTAIRS"]['tBodyAccMag-mean()'],hist = False, label = 'Laying')

# %% [markdown]
# We can also visualize this insight using box-plots

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Activity', y='tBodyAccMag-mean()',data=df_train, showfliers=False)
plt.ylabel('Body Acceleration Magnitude mean')
plt.title("Boxplot of tBodyAccMag-mean() column across various activities")
plt.axhline(y=-0.7, xmin=0.05,dashes=(3,3))
plt.axhline(y=0.020, xmin=0.35, dashes=(3,3))
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# 1. Using box-plot we are getting the insight that:
#
#     if tBodyAccMag-mean()<=-0.8:
#         Activity = "static"
#     else if tBodyAccMag-mean()>=-0.6:
#         Activity = "dynamic"
#
# 2. We can also observe that acceleration is greater while walking downstairs

# %% [markdown]
# ### 4.2 Analysis of angle between X and Y axes and gravity mean feature:

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Activity', y='angle(X,gravityMean)', data=df_train, showfliers=False)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,dashes=(3,3))
plt.ylabel("Angle between X-axis and gravityMean")
plt.title('Box plot of angle(X,gravityMean) column across various activities')
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %% [markdown]
# - This analysis gives an insight of seperation of Laying activites from other activities. We can observe that:
#
#     if angle(X,gravityMean) > 0.01:
#         Activity = "LAYING"
#     else:
#         Activity = "OTHER"

# %% [markdown]
# Similarly if we analyze the angle between Y axes and gravity mean feature:

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Activity', y='angle(Y,gravityMean)', data = df_train, showfliers=False)
plt.ylabel("Angle between Y-axis and gravityMean")
plt.title('Box plot of angle(Y,gravityMean) column across various activities')
plt.xticks(rotation = 90)
plt.axhline(y=-0.35, xmin=0.01, dashes=(3,3))

# %% [markdown]
# We can see that activity 'LAYING' stands out from other activites but with some classification error.

# %% [markdown]
# ### 4.3 Visualizing data using t-Distributed Stochastic Neighbor Embedding (t-SNE)

# %% [markdown]
# We can visualize the the seperability of all the activites using t-SNE in a 2D space.

# %%
from sklearn.manifold import TSNE

X_for_tsne = df_train.drop(['subject', 'Activity'], axis=1)

# %time
tsne = TSNE(random_state = 42, n_components=2, verbose=1, perplexity=50, n_iter=1000).fit_transform(X_for_tsne)
# Out:
# Wall time: 0 ns
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.274s...
# [t-SNE] Computed neighbors for 7352 samples in 32.199s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.058258
# [t-SNE] KL divergence after 1000 iterations: 1.283563

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x =tsne[:, 0], y = tsne[:, 1], hue = df_train["Activity"],palette="bright")

# %% [markdown]
# ## 5. Modeling

# %% [markdown]
# ### 5.1 Importing classification models

# %%
from sklearn. linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 5.2 Defining global reusable function

# %%
def best_grid_search_results(model):
    print("Best estimator : ", model.best_estimator_)
    print("Best set of parameters : ", model.best_params_)
    print("Best score : ", model.best_score_)
    
def plot_confusion_matrix(y_test, y_true):
    cm = confusion_matrix(y_test,y_pred)
    df_cm = pd.DataFrame(cm, columns=np.unique(y_true), index = np.unique(y_true))
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    plt.figure(figsize = (10,7))
    plt.ylim([1.5, -.5])
    sns.set(font_scale=1.4)#for label size
    sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 12})# font size

# %% [markdown]
# ### 5.3 Preparing Training and Test data for Machine Learning Models

# %%
X_train = df_train.drop(['subject', 'Activity'], axis=1)
y_train = df_train.Activity
X_test = df_test.drop(['subject', 'Activity'], axis=1)
y_test = df_test.Activity
print('Training data size : ', X_train.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (7352, 561)
# Test data size :  (2947, 561)

# %% [markdown]
# ### 5.4 Comparison of Classifiers without Hyperparameter tuning

# %%
classifiers = [
    LogisticRegression(),
    LinearSVC(tol=0.00005),
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(7), # 6 different labels 0-6
    RandomForestClassifier(200)
]

names = []
scores = []

for clf in classifiers:
    clf = clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(accuracy_score(y_pred, y_test))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
score_df
# Out:
#                            Score
# Model
# LogisticRegression      0.961995
# LinearSVC               0.969121
# SVC                     0.940278
# DecisionTreeClassifier  0.857482
# KNeighborsClassifier    0.902273
# RandomForestClassifier  0.925687

# %%
ax = score_df.plot.bar()
ax.set_xticklabels(score_df.index, rotation=45, fontsize=10)
# Out:
# [Text(0, 0, 'LogisticRegression'),
#  Text(0, 0, 'LinearSVC'),
#  Text(0, 0, 'SVC'),
#  Text(0, 0, 'DecisionTreeClassifier'),
#  Text(0, 0, 'KNeighborsClassifier'),
#  Text(0, 0, 'RandomForestClassifier')]

# %% [markdown]
# Without hyperparameter tuning, we can see that Logistic regression has the highest accuracy. Now lets check which classifier performs best after hyperparameter tuning.

# %% [markdown]
# ### 5.5 Comparison of Classifiers with Hyperparameter tuning

# %%
# for storing the scores of classifiers after hyperparameter tuning
scores_tuned = []

# %% [markdown]
# **1. Logistic Regression**

# %%
params = {'C':np.arange(10,61,10), 'penalty':['l2','l1']}
lr = LogisticRegression()
lr_tuned = GridSearchCV(lr, param_grid=params, cv=5)
lr_tuned.fit(X_train, y_train)
y_pred = lr_tuned.predict(X_test)

lr_accuracy = accuracy_score(y_test, y_pred)

print('LR Classifier Accuracy: ', lr_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# LR Classifier Accuracy:  0.9623345775364778
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.95      1.00      0.97       496
# WALKING_DOWNSTAIRS       1.00      0.97      0.98       420
#   WALKING_UPSTAIRS       0.98      0.95      0.96       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
scores_tuned.append(lr_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284]

# %%
best_grid_search_results(lr_tuned)
# Out:
# Best estimator :  LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
# Best set of parameters :  {'C': 10, 'penalty': 'l2'}
# Best score :  0.941240478781284

# %% [markdown]
# **2. Support Vector Machine**

# %% [markdown]
# - **Linear SVM**

# %%
params = {'C':np.arange(1,12,2)}
lr_svm = LinearSVC(tol=0.00005)
lr_svm_tuned = GridSearchCV(lr_svm, param_grid=params)
lr_svm_tuned.fit(X_train, y_train)
y_pred = lr_svm_tuned.predict(X_test)

lr_svm_accuracy = accuracy_score(y_test, y_pred)


print('Linear SVM Classifier Accuracy: ', lr_svm_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Linear SVM Classifier Accuracy:  0.9647098744485918
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.86      0.92       491
#           STANDING       0.89      0.98      0.93       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.97      0.96      0.96      2947

# %%
scores_tuned.append(lr_svm_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284, 0.9465451577801959]

# %%
best_grid_search_results(lr_svm_tuned)
# Out:
# Best estimator :  LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=5e-05,
#           verbose=0)
# Best set of parameters :  {'C': 1}
# Best score :  0.9465451577801959

# %% [markdown]
# - **Kernel SVM**

# %%
params = {'C':[2,4,8,16],'gamma': [0.125, 0.250, 0.5, 1]}
kernel_svm = SVC(kernel='rbf')
kernel_svm_tuned = GridSearchCV(kernel_svm, param_grid=params)
kernel_svm_tuned.fit(X_train, y_train)
y_pred = kernel_svm_tuned.predict(X_test)

kernel_svm_accuracy = accuracy_score(y_test, y_pred)

print('Kernel SVM Classifier Accuracy: ', kernel_svm_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Kernel SVM Classifier Accuracy:  0.9416355615880556
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      0.98      0.99       537
#            SITTING       0.97      0.91      0.94       491
#           STANDING       0.94      0.95      0.95       532
#            WALKING       0.98      0.92      0.95       496
# WALKING_DOWNSTAIRS       0.81      0.92      0.86       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.94      2947
#          macro avg       0.94      0.94      0.94      2947
#       weighted avg       0.95      0.94      0.94      2947

# %%
scores_tuned.append(kernel_svm_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284, 0.9465451577801959, 0.8813928182807399]

# %%
best_grid_search_results(kernel_svm_tuned)
# Out:
# Best estimator :  SVC(C=2, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.125, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Best set of parameters :  {'C': 2, 'gamma': 0.125}
# Best score :  0.8813928182807399

# %% [markdown]
# **3. Decision Tree Classifier**

# %%
params = {'max_depth':np.arange(2,10,2)}
dtc = DecisionTreeClassifier()
dtc_tuned = GridSearchCV(dtc, param_grid=params)
dtc_tuned.fit(X_train, y_train)
y_pred = dtc_tuned.predict(X_test)

dtc_accuracy = accuracy_score(y_test, y_pred)

print('Decision Tree Classifier Accuracy: ', dtc_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Decision Tree Classifier Accuracy:  0.8096369189005769
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.78      0.81      0.79       491
#           STANDING       0.82      0.79      0.80       532
#            WALKING       0.65      0.88      0.75       496
# WALKING_DOWNSTAIRS       0.94      0.62      0.75       420
#   WALKING_UPSTAIRS       0.77      0.71      0.74       471
#
#           accuracy                           0.81      2947
#          macro avg       0.83      0.80      0.80      2947
#       weighted avg       0.83      0.81      0.81      2947

# %%
scores_tuned.append(dtc_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284, 0.9465451577801959, 0.8813928182807399, 0.844532100108814]

# %%
best_grid_search_results(dtc_tuned)
# Out:
# Best estimator :  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# Best set of parameters :  {'max_depth': 4}
# Best score :  0.844532100108814

# %% [markdown]
# **4. K-Nearest Neighbor**

# %%
params = {'n_neighbors': np.arange(1, 25)}
knn = KNeighborsClassifier()
knn_tuned = GridSearchCV(knn, param_grid=params, cv=5)
knn_tuned.fit(X_train, y_train)
y_pred = knn_tuned.predict(X_test)

knn_accuracy = accuracy_score(y_test, y_pred)

print('K-Nearest Neighbor Classifier Accuracy: ', knn_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# K-Nearest Neighbor Classifier Accuracy:  0.9077027485578555
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.92      0.82      0.86       491
#           STANDING       0.85      0.93      0.89       532
#            WALKING       0.84      0.99      0.91       496
# WALKING_DOWNSTAIRS       0.96      0.78      0.86       420
#   WALKING_UPSTAIRS       0.90      0.90      0.90       471
#
#           accuracy                           0.91      2947
#          macro avg       0.91      0.90      0.90      2947
#       weighted avg       0.91      0.91      0.91      2947

# %%
scores_tuned.append(knn_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284,
#  0.9465451577801959,
#  0.8813928182807399,
#  0.844532100108814,
#  0.9031556039173014]

# %%
best_grid_search_results(knn_tuned)
# Out:
# Best estimator :  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=16, p=2,
#                      weights='uniform')
# Best set of parameters :  {'n_neighbors': 16}
# Best score :  0.9031556039173014

# %% [markdown]
# **5. Random Forests Classifier**

# %%
params = {'n_estimators': np.arange(20,101,10), 'max_depth':np.arange(2,16,2)}
rf_classifier = RandomForestClassifier()
rf_classifier_tuned = GridSearchCV(rf_classifier, param_grid=params)
rf_classifier_tuned.fit(X_train, y_train)
y_pred = rf_classifier_tuned.predict(X_test)

rf_accuracy = accuracy_score(y_test, y_pred)

print('Random Forests Classifier Accuracy: ', rf_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Random Forests Classifier Accuracy:  0.8934509670851714
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.89      0.82      0.86       491
#           STANDING       0.85      0.91      0.88       532
#            WALKING       0.81      0.98      0.89       496
# WALKING_DOWNSTAIRS       0.96      0.76      0.85       420
#   WALKING_UPSTAIRS       0.89      0.86      0.87       471
#
#           accuracy                           0.89      2947
#          macro avg       0.90      0.89      0.89      2947
#       weighted avg       0.90      0.89      0.89      2947

# %%
scores_tuned.append(rf_classifier_tuned.best_score_)
scores_tuned
# Out:
# [0.941240478781284,
#  0.9465451577801959,
#  0.8813928182807399,
#  0.844532100108814,
#  0.9031556039173014,
#  0.9144450489662677]

# %%
best_grid_search_results(rf_classifier_tuned)
# Out:
# Best estimator :  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=6, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=40,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Best set of parameters :  {'max_depth': 6, 'n_estimators': 40}
# Best score :  0.9144450489662677

# %% [markdown]
# ### 5.6 Comparison

# %%
score_df = pd.DataFrame({'Model': names, 'Score': scores_tuned}).set_index('Model')
score_df
# Out:
#                            Score
# Model
# LogisticRegression      0.941240
# LinearSVC               0.946545
# SVC                     0.881393
# DecisionTreeClassifier  0.844532
# KNeighborsClassifier    0.903156
# RandomForestClassifier  0.914445

# %%
ax = score_df.plot.bar()
ax.set_xticklabels(score_df.index, rotation=45, fontsize=10)
# Out:
# [Text(0, 0, 'LogisticRegression'),
#  Text(0, 0, 'LinearSVC'),
#  Text(0, 0, 'SVC'),
#  Text(0, 0, 'DecisionTreeClassifier'),
#  Text(0, 0, 'KNeighborsClassifier'),
#  Text(0, 0, 'RandomForestClassifier')]

# %% [markdown]
# From these results it's evident that Linear SVM has the best score after hyperparameter tuning. Now lets retrain the model with best parameters and save it.

# %% [markdown]
# ### 5.7 Saving the best model

# %% [markdown]
# Linear SVM best parameters are:

# %%
lr_svm_tuned.best_params_
# Out:
# {'C': 1}

# %%
lr_svm = LinearSVC(tol=0.00005, C=7)
lr_svm.fit(X_train, y_train)
y_pred = lr_svm.predict(X_test)
lr_svm_accuracy = accuracy_score(y_test, y_pred)


print('Linear SVM Classifier Accuracy: ', lr_svm_accuracy)
print('Classification Report: \n', classification_report(y_test, y_pred))
# Out:
# Linear SVM Classifier Accuracy:  0.9647098744485918
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.86      0.91       491
#           STANDING       0.89      0.98      0.93       532
#            WALKING       0.97      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.97      0.97       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.97      0.96      0.96      2947

# %%
from sklearn.externals import joblib
filename = 'best_model'
joblib.dump(lr_svm, filename)
# Out:
# ['best_model']

# %%
loaded_model = joblib.load(filename)

result = loaded_model.predict(X_test)
print(result)
# Out:
# ['STANDING' 'STANDING' 'STANDING' ... 'WALKING_UPSTAIRS'
#  'WALKING_UPSTAIRS' 'WALKING_UPSTAIRS']

# %%
sample = X_test.iloc[0:1, :]
sample
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.674302         -0.894088  ...                         0.071645
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                         -0.33037                        -0.705974
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                               0.16292
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# ...

# %%
result = loaded_model.predict(sample)
print(result)
# Out:
# ['STANDING']
